# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### EDA

# %%
data = pd.read_csv("data/HR.csv")
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
data.isna().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# sales                    0
# salary                   0
# dtype: int64

# %%
data['sales'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
data = pd.get_dummies(data)

# %%
data.corr()
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.105021       -0.142970
# last_evaluation                  0.105021         1.000000        0.349333
# number_project                  -0.142970         0.349333        1.000000
# average_montly_hours            -0.020048         0.339742        0.417211
# time_spend_company              -0.100866         0.131591        0.196786
# Work_accident                    0.058697        -0.007104       -0.004741
# left                            -0.388375         0.006567        0.023787
# promotion_last_5years            0.025605        -0.008684       -0.006064
# sales_IT                         0.006373         0.001269        0.003287
# sales_RandD                      0.006615        -0.005471        0.009703
# sales_accounting                -0.028649         0.002193        0.004189
# ...

# %%
correlation = data.corr()
plt.figure(figsize=(20,20))
sns.heatmap(correlation, vmax=1, square=True,annot=True,cmap='cubehelix')
plt.title('Correlation between different features')
# Out:
# Text(0.5, 1.0, 'Correlation between different features')

# %%
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales_IT  \
# 0                   3              0     1                      0     False
# 1                   6              0     1                      0     False
# 2                   4              0     1                      0     False
# 3                   5              0     1                      0     False
# 4                   3              0     1                      0     False
#
# ...

# %%
cols = data.columns.tolist()
cols
# Out:
# ['satisfaction_level',
#  'last_evaluation',
#  'number_project',
#  'average_montly_hours',
#  'time_spend_company',
#  'Work_accident',
#  'left',
#  'promotion_last_5years',
#  'sales_IT',
#  'sales_RandD',
#  'sales_accounting',
#  'sales_hr',
#  'sales_management',
#  'sales_marketing',
#  'sales_product_mng',
#  'sales_sales',
#  'sales_support',
#  'sales_technical',
#  'salary_high',
#  'salary_low',
#  'salary_medium']

# %% [markdown]
# ### Splitting X and Y

# %%
X = data.drop('left',axis=1).values
y = data['left'].values

# %% [markdown]
# ### PCA

# %%
from sklearn.decomposition import PCA
import numpy as np
pca = PCA().fit(X)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0, 0.5, 'Cumulative explained variance')

# %%
pca.explained_variance_ratio_

# %%
#cumulative sum in percentage
np.cumsum(pca.explained_variance_ratio_)*100
# Out:
# array([ 99.79995343,  99.88688772,  99.93427002,  99.95255452,
#         99.96204127,  99.96862045,  99.97359777,  99.97835601,
#         99.98267363,  99.98562639,  99.9880639 ,  99.99041742,
#         99.9926124 ,  99.99467198,  99.99666649,  99.9982824 ,
#         99.99920758, 100.        , 100.        , 100.        ])

# %%
from sklearn.decomposition import PCA 
sklearn_pca = PCA(n_components=10)
X_PCA = sklearn_pca.fit_transform(X)

# %%
#information disctribution
sklearn_pca.explained_variance_ratio_
# Out:
# array([9.97999534e-01, 8.69342838e-04, 4.73823077e-04, 1.82844960e-04,
#        9.48675250e-05, 6.57917451e-05, 4.97732563e-05, 4.75824037e-05,
#        4.31762170e-05, 2.95275424e-05])

# %%
#cumulative sum in percentage
np.cumsum(sklearn_pca.explained_variance_ratio_)*100
# Out:
# array([99.79995343, 99.88688772, 99.93427002, 99.95255452, 99.96204127,
#        99.96862045, 99.97359777, 99.97835601, 99.98267363, 99.98562639])

# %%
#information lose
(100-99.98562639)
# Out:
# 0.01437361000000692

# %%
X.shape
# Out:
# (14999, 20)

# %%
X_PCA.shape
# Out:
# (14999, 10)

# %% [markdown]
# ## We have reduced the features from 20 to 10 by loosing 0.0143 % of information

# %%
X_PCA
# Out:
# array([[-4.40683291e+01, -6.92222779e-01,  1.20822904e+00, ...,
#         -9.44809074e-02,  5.66396055e-02,  5.75284638e-03],
#        [ 6.09678167e+01,  2.35464381e+00,  9.06662571e-02, ...,
#         -1.36858986e-01,  7.34119261e-02,  4.18117319e-02],
#        [ 7.09804269e+01,  9.26407449e-01, -2.30581702e+00, ...,
#         -1.02715224e-01,  5.65655420e-02, -7.02328725e-03],
#        ...,
#        [-5.80674796e+01, -6.13560924e-01,  1.06795999e+00, ...,
#         -3.18711854e-01,  3.53574207e-01,  5.53221656e-02],
#        [ 7.89696701e+01,  5.68773207e-01, -1.30138350e+00, ...,
#         -3.06502426e-01,  3.44690976e-01,  3.40301407e-02],
#        [-4.30684025e+01, -7.09962902e-01,  1.20210992e+00, ...,
#         -3.18076793e-01,  3.53695616e-01,  5.42034084e-02]])

# %% [markdown]
# ### train test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_PCA,y,test_size=0.2, random_state=30, stratify=y)

# %% [markdown]
# ### SVC

# %%
from sklearn.svm import SVC  #SVC - Supoprt Vector Classifier
cls=SVC()

from sklearn.model_selection import GridSearchCV
parameters = {'C':[0.001,0.1], 'gamma':[0.1],'kernel':['rbf']}

#C - Regularization - squared l2 error is calculated
#gamma - Fit of the model
#kernal - kernal to be used 

grid=GridSearchCV(cls, parameters,cv=5)
grid.fit(X_train, y_train)

#to get the best parameter for the model
grid.best_params_

# %%
svclassifier=SVC(C=0.1,gamma=0.1,kernel='rbf',probability=True)
svclassifier.fit(X_train,y_train)
ypred=svclassifier.predict(X_test)
#accuracy
from sklearn.metrics import accuracy_score
accuracy_score(y_test,ypred)

# %%
#END
