# %% [markdown]
# # SVM - Iris Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### EDA

# %%
data = pd.read_csv("../data/iris.csv")
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### splitting x and y

# %%
X=data.drop(['Id','Species'],axis=1)
y=data['Species']

# %% [markdown]
# ### train test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=30, stratify=y)

# %% [markdown]
# ### SVC

# %%
from sklearn.svm import SVC  #SVC - Supoprt Vector Classifier
cls=SVC()

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'C':[0.001,0.1,10], 'gamma':[0.1,0.01],'kernel':['rbf','linear']}

#C - Regularization - squared l2 error is calculated
#gamma - Fit of the model
#kernal - kernal to be used

# %%
grid=GridSearchCV(cls, parameters,cv=5)
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.001, 0.1, 10], 'gamma': [0.1, 0.01],
#                          'kernel': ['rbf', 'linear']})

# %%
#to get the best parameter for the model
grid.best_params_
# Out:
# {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
svclassifier=SVC(C=10,gamma=0.1,kernel='rbf',probability=True)
svclassifier.fit(X_train,y_train)
# Out:
# SVC(C=10, gamma=0.1, probability=True)

# %%
ypred=svclassifier.predict(X_test)

# %%
#accuracy
from sklearn.metrics import accuracy_score
accuracy_score(y_test,ypred)
# Out:
# 1.0

# %%
#confusison matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,ypred)
# Out:
# array([[10,  0,  0],
#        [ 0, 10,  0],
#        [ 0,  0, 10]], dtype=int64)

# %% [markdown]
# ### roc_auc_score

# %%
from sklearn.metrics import roc_auc_score
rfc_probs = svclassifier.predict_proba(X_test)
rfc_probs
# Out:
# array([[0.01653876, 0.022831  , 0.96063024],
#        [0.00895233, 0.01863147, 0.9724162 ],
#        [0.96425574, 0.02491958, 0.01082468],
#        [0.01549568, 0.97687489, 0.00762943],
#        [0.01746283, 0.97790459, 0.00463258],
#        [0.97440961, 0.01561476, 0.00997562],
#        [0.97111681, 0.01810406, 0.01077913],
#        [0.9676529 , 0.02168332, 0.01066378],
#        [0.01632785, 0.02482965, 0.9588425 ],
#        [0.01100405, 0.92983611, 0.05915983],
#        [0.00871109, 0.98206481, 0.0092241 ],
#        [0.01008855, 0.00838278, 0.98152868],
#        [0.00836863, 0.98395137, 0.00767999],
#        [0.01120693, 0.00299148, 0.98580159],
#        [0.96809723, 0.02157423, 0.01032854],
#        [0.96376048, 0.02451849, 0.01172103],
#        [0.9300069 , 0.05648868, 0.01350441],
#        [0.01799091, 0.53850849, 0.4435006 ],
#        [0.97065574, 0.01940738, 0.00993688],
#        [0.01186736, 0.71027348, 0.27785916],
#        [0.02240659, 0.16549565, 0.81209776],
#        [0.96124878, 0.02764998, 0.01110125],
#        [0.01078426, 0.97879273, 0.01042301],
#        [0.00812774, 0.92382518, 0.06804708],
#        [0.01028073, 0.37379729, 0.61592198],
#        [0.01862817, 0.92788146, 0.05349037],
#        [0.00886668, 0.00253193, 0.98860139],
#        [0.0108876 , 0.1552481 , 0.83386429],
#        [0.97052544, 0.0196155 , 0.00985906],
#        [0.01640515, 0.04397284, 0.93962201]])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,ypred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       1.00      1.00      1.00        10
#  Iris-virginica       1.00      1.00      1.00        10
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30

# %%
#END
