# %% [markdown]
# # Linear Regression Analysis for Predicting Wave Heights from Meteorological and Oceanographic Data

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# ### Load dataset

# %%
data=pd.read_csv('data/35.waves.csv')
data.head()
# Out:
#    hh  WDIR  WSPD  GST   DPD   APD  MWD    PRES  ATMP  WTMP  DEWP  WVHT
# 0   1    23   3.0  3.6  4.17  3.33  349  1019.1   4.7   5.1   4.2  0.39
# 1   2    30   2.9  3.3  5.26  4.21  358  1018.8   4.6   4.8   4.1  0.65
# 2   3   360   2.2  2.5  5.88  4.79   11  1018.3   4.6   4.7   4.2  0.90
# 3   4   355   2.5  3.1  5.88  4.95   23  1018.1   4.6   4.6   4.2  0.91
# 4   5   355   3.5  4.5  6.25  4.98   26  1018.3   4.5   4.6   4.0  0.88

# %% [markdown]
# ### Data preprocessing

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# hh      0
# WDIR    0
# WSPD    0
# GST     0
# DPD     0
# APD     0
# MWD     0
# PRES    0
# ATMP    0
# WTMP    0
# DEWP    0
# WVHT    0
# dtype: int64

# %%
data.dtypes
# Out:
# hh        int64
# WDIR      int64
# WSPD    float64
# GST     float64
# DPD     float64
# APD     float64
# MWD       int64
# PRES    float64
# ATMP    float64
# WTMP    float64
# DEWP    float64
# WVHT    float64
# dtype: object

# %%
data.shape
# Out:
# (3886, 12)

# %%
data.size
# Out:
# 46632

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3886 entries, 0 to 3885
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   hh      3886 non-null   int64
#  1   WDIR    3886 non-null   int64
#  2   WSPD    3886 non-null   float64
#  3   GST     3886 non-null   float64
#  4   DPD     3886 non-null   float64
#  5   APD     3886 non-null   float64
#  6   MWD     3886 non-null   int64
#  7   PRES    3886 non-null   float64
#  8   ATMP    3886 non-null   float64
#  9   WTMP    3886 non-null   float64
#  10  DEWP    3886 non-null   float64
#  11  WVHT    3886 non-null   float64
# dtypes: float64(9), int64(3)
# memory usage: 364.4 KB

# %% [markdown]
# ### Correlation Analysis

# %%
print("\nCorrelation Matrix:")
corr_matrix = data.corr()
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()
# Out:
# Correlation Matrix:

# %% [markdown]
# ### Data Visualization

# %%
# Boxplot for a specific column:WSPD
plt.figure(figsize=(8, 4))
sns.boxplot(x=data['WSPD'])
plt.title("Boxplot for Wind Speed (WSPD)")
plt.show()

# Boxplot for the target variable :WVHT
plt.figure(figsize=(8, 4))
sns.boxplot(x=data['WVHT'])
plt.title("Boxplot for Wave Height (WVHT)")
plt.show()

# lmplot to show the relationship between WSPD(feature) and WVHT(target)
sns.lmplot(x='WSPD', y='WVHT', data=data, aspect=2, height=6)
plt.title("Linear Relationship between Wind Speed (WSPD) and Wave Height (WVHT)")
plt.show()

# lmplot for another feature:PRES vs. the target
sns.lmplot(x='PRES', y='WVHT', data=data, aspect=2, height=6)
plt.title("Linear Relationship between Pressure (PRES) and Wave Height (WVHT)")
plt.show()

# %% [markdown]
# ### Splitting the Data into Features (X) and Target (Y)

# %%
target = 'WVHT'  
features = data.columns.difference([target])
X = data[features]
y = data[target]

# %% [markdown]
# ### Scaling the features

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ### Splitting the data into Training and Testing Sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# ### linear Regression Modeling

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Predictions

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([0.83085117, 0.20274021, 0.09494341, 0.30438781, 0.64100624,
#        0.59212653, 0.58242745, 0.36297972, 0.64980518, 0.42273588,
#        0.87217584, 0.77303411, 0.42644487, 0.40732306, 0.54370479,
#        0.85307494, 0.70316676, 0.33966544, 0.89996282, 1.75635902,
#        0.75889085, 0.26754667, 0.89950531, 0.26832661, 0.17789206,
#        0.35050111, 0.33237217, 0.52874359, 0.58995988, 0.42476371,
#        0.64626802, 1.37879851, 0.58233212, 0.71490934, 0.26264922,
#        0.63992742, 1.04485206, 0.33670991, 0.60240401, 0.25073618,
#        0.96574733, 0.45785706, 0.29836495, 0.72262904, 0.48771679,
#        0.6563211 , 0.53417275, 0.24232942, 0.2500647 , 0.7695412 ,
#        0.47760676, 0.46150141, 1.16808389, 1.64234486, 0.425315  ,
#        0.4665987 , 1.63858851, 0.74451713, 0.75990929, 0.62998495,
#        0.36912035, 0.21478556, 0.85159182, 0.6953839 , 0.48470629,
#        0.62667512, 0.59076763, 1.00289637, 0.41558381, 1.06071656,
#        1.18558665, 0.8366687 , 0.92826019, 1.57372121, 0.59886795,
#        1.35919687, 0.39130295, 1.1920343 , 1.1055492 , 0.5538049 ,
#        0.22407832, 0.41059743, 0.51324887, 0.76123073, 0.54131094,
#        0.5688417 , 0.21667584, 0.21365825, 0.89290691, 0.4765874 ,
#        0.30661915, 0.89092214, 0.4757869 , 1.34716322, 1.16837752,
#        0.25409789, 0.26805845, 0.30639372, 0.49648362, 0.71392559,
#        0.25764831, 0.4482946 , 1.07402478, 0.47428657, 0.31771934,
#        0.27202312, 0.29672864, 0.49716322, 1.21160067, 0.54911162,
#        0.37357747, 0.9618271 , 0.91289739, 0.41788004, 0.84818155,
#        0.25500527, 0.49383823, 1.49894476, 0.21473689, 0.53440608,
#        0.38555238, 0.13959304, 0.9524289 , 0.13361713, 0.23807963,
#        0.67452526, 1.58918447, 0.30833226, 0.63044764, 1.04725691,
#        0.52695445, 0.15896886, 1.48262475, 1.34327873, 0.33618009,
#        0.29967743, 1.43903109, 1.0343912 , 0.11684503, 0.33305273,
#        0.21708417, 0.2662213 , 1.004817  , 0.21699992, 0.59182329,
#        0.67149152, 0.21968118, 0.43449804, 0.37808262, 0.2580136 ,
#        0.50091308, 0.21843568, 0.44478727, 0.5973179 , 0.60135421,
#        0.62685112, 1.19243466, 0.42905151, 1.31515069, 0.42267467,
#        0.52057251, 1.2695533 , 1.6400741 , 0.12464529, 0.89038518,
#        0.45622118, 1.47496692, 0.73201618, 0.55798242, 0.58379538,
#        0.44901372, 0.36883693, 0.25107791, 1.01755575, 1.0094058 ,
#        0.55359285, 0.87597704, 1.0701213 , 0.64712873, 0.61291801,
#        0.61585983, 0.57649843, 0.75935607, 0.40615438, 0.20645191,
#        0.50735786, 0.86753486, 0.51153928, 0.77254887, 1.33862973,
#        1.3735417 , 0.51407896, 1.35594866, 0.30592394, 0.63114891,
#        0.33280847, 0.38776481, 0.36832956, 0.90403698, 0.31178819,
#        0.74482277, 0.36208677, 0.36670731, 0.61083758, 0.91829799,
#        1.12314476, 0.23094608, 1.14641133, 0.75374387, 1.47393349,
#        1.07530243, 1.71149993, 0.36070826, 1.39276105, 0.88159315,
#        0.32967288, 0.42642232, 0.71379128, 1.33150897, 0.98763224,
#        0.69454778, 0.49344145, 0.59615803, 1.04144473, 0.21245744,
#        0.39891943, 0.54007952, 1.0625705 , 0.08101189, 2.01916401,
#        1.03696044, 0.28789276, 0.43218525, 0.3211663 , 0.28729708,
#        0.39378635, 0.25617515, 1.15852724, 0.50681315, 1.04221606,
#        0.54493048, 0.76975023, 0.63231909, 0.66293827, 1.47158582,
#        0.53129559, 0.86842003, 0.30677165, 0.54026898, 0.75956578,
#        1.10207996, 0.41820058, 0.38520969, 0.79873454, 0.2238643 ,
#        0.2998126 , 0.76109695, 0.84200437, 0.58967072, 1.11524905,
#        1.08283341, 1.22547353, 0.91643232, 1.06587784, 0.78436328,
#        0.73447507, 0.18862582, 0.18066966, 1.65937506, 0.31337707,
#        1.28522288, 0.47134637, 0.22766529, 0.6310408 , 0.66047873,
#        0.74141979, 0.98040926, 0.13946564, 0.17838728, 0.33796613,
#        0.26016039, 1.07328454, 0.81401948, 0.47133273, 1.17017168,
#        0.53450834, 1.34839297, 0.28791783, 0.91064127, 1.36017942,
#        0.68007101, 0.58345749, 0.91990279, 1.37303709, 0.25274684,
#        0.3283705 , 0.58825117, 0.21295553, 1.03845391, 1.64457256,
#        0.33456637, 0.95824592, 0.55401591, 0.31754036, 0.58836333,
#        0.70244743, 0.36754016, 0.30906907, 0.15743162, 0.67836276,
#        0.66070998, 0.97302129, 0.40850528, 0.45464716, 0.74194252,
#        0.89340364, 1.34348554, 0.69714806, 0.23668491, 0.16491495,
#        1.20493764, 0.2285702 , 1.40361833, 0.57543207, 0.51155506,
#        0.46390551, 0.64417591, 0.52281326, 0.34386866, 0.57753259,
#        0.19380804, 0.46132347, 0.02495393, 1.43563249, 1.08637375,
#        0.80652894, 0.29095921, 0.76837672, 0.99553076, 0.49847028,
#        0.53864517, 0.62895255, 0.60324463, 0.62997229, 0.33411924,
#        0.8129903 , 0.3685243 , 0.33065573, 0.79470634, 0.66740396,
#        1.07689439, 0.5189113 , 0.22238235, 0.75184013, 0.83803068,
#        0.23561887, 0.3553272 , 0.83252371, 0.90856702, 0.51678978,
#        0.3635404 , 0.880336  , 1.492721  , 0.88012896, 0.50062565,
#        0.79406201, 1.14092563, 0.55316455, 0.47679071, 0.55389519,
#        0.09196813, 0.38342262, 1.28305611, 0.76679258, 0.35989912,
#        0.72671841, 0.16076663, 0.56679239, 1.04971963, 0.22782042,
#        0.11286352, 0.08171309, 0.41647683, 0.30188066, 0.80574362,
#        0.62531462, 0.98263751, 1.0000042 , 0.33353679, 0.59975906,
#        0.30670015, 0.27929583, 0.27276642, 0.47918726, 0.74886726,
#        0.66990299, 0.57908074, 1.38411012, 0.42619818, 0.40525467,
#        0.22786186, 0.48111711, 0.59612301, 0.55569992, 0.39017629,
#        0.69947472, 1.55758469, 0.57340971, 1.26769756, 0.7717988 ,
#        0.78413144, 0.17025159, 1.6148638 , 0.7022896 , 0.84818084,
#        0.25180558, 0.62633146, 1.18070201, 0.39909722, 0.36931692,
#        0.49429387, 0.32814887, 0.81643683, 0.28753796, 0.41406628,
#        0.3762401 , 0.64885792, 0.57317389, 1.51502761, 0.41636981,
#        0.22680745, 0.37628137, 0.50290099, 0.87895991, 1.2805549 ,
#        0.27946157, 0.54332211, 0.91797837, 0.48628017, 1.87337666,
#        0.157654  , 0.40278417, 0.29230075, 0.49342051, 1.23343062,
#        0.19668944, 0.45133856, 0.66285725, 0.59595479, 0.31254014,
#        1.39672091, 0.77968462, 1.1161139 , 0.42324309, 0.90013325,
#        0.62995454, 0.37135074, 1.9011245 , 0.32730748, 1.04879418,
#        0.35588031, 0.85603614, 1.87125364, 0.61942849, 0.41288627,
#        0.33244693, 1.16032914, 0.76466108, 0.260475  , 0.91907452,
#        0.42686334, 0.74053226, 0.50187331, 0.21154577, 0.54454699,
#        0.9609299 , 0.51430292, 1.08236806, 0.69219665, 0.80837704,
#        0.76325024, 0.95334849, 1.33588705, 0.34260074, 0.46502782,
#        0.59923843, 0.39436933, 0.18785523, 0.49684322, 0.56509892,
#        0.69647568, 0.35421307, 1.36980765, 0.05869492, 0.84452621,
#        0.25938305, 0.82214129, 0.92888268, 0.27927347, 0.81494858,
#        0.52360214, 0.90473169, 0.91731022, 0.45104663, 0.59176808,
#        1.13212494, 0.78215946, 0.50362027, 0.40078787, 0.25616654,
#        0.62010522, 1.1953405 , 0.31983777, 0.5213332 , 0.70997416,
#        1.89431087, 0.63531227, 0.43045598, 0.2620689 , 1.03517381,
#        1.12534629, 0.34841125, 0.61027635, 0.36997602, 0.23738965,
#        0.65051439, 1.2350662 , 0.87643293, 0.12375924, 1.26431768,
#        0.14956041, 0.57780369, 0.82795453, 0.19503861, 0.69810997,
#        1.29748573, 0.14642393, 0.91486283, 0.45944879, 0.93174101,
#        0.17224958, 1.08191129, 0.45741919, 0.57119982, 0.43361682,
#        0.3404969 , 0.75486993, 0.83359681, 0.78165463, 0.21494725,
#        0.60231616, 0.76573825, 0.64887457, 0.4683341 , 0.57102058,
#        0.49405252, 0.30059376, 0.08382922, 0.9272017 , 1.56085167,
#        0.35694043, 1.34574423, 0.90114094, 0.41032171, 0.45203371,
#        0.20448339, 1.14651949, 0.29739517, 0.52831285, 0.79739513,
#        1.44574148, 0.60475936, 1.3477459 , 0.17939532, 0.57351307,
#        0.50344036, 0.21486283, 1.0209528 , 0.1568095 , 0.392612  ,
#        0.47435629, 0.64563002, 0.25470756, 0.47978266, 0.39070466,
#        0.53466203, 0.81638305, 0.27766769, 1.14975088, 0.42975861,
#        0.82625665, 0.87767517, 1.51298121, 0.66587876, 0.98447939,
#        1.21676707, 0.40755202, 0.69371136, 0.34623367, 0.33481441,
#        0.83011271, 0.36925443, 0.16039485, 0.42865952, 0.44555484,
#        1.13695777, 0.39974897, 0.16549467, 0.71882837, 1.06398242,
#        0.44559625, 0.58609129, 0.36680864, 0.80350116, 0.26388291,
#        0.31103658, 1.54402104, 0.92065911, 0.23919678, 0.63091549,
#        0.23760347, 0.50932817, 1.38088537, 0.71797616, 0.33841886,
#        1.4256921 , 0.58726672, 0.32892565, 0.27964742, 0.82257842,
#        0.66720927, 0.40321443, 0.55472375, 1.14799296, 0.23602322,
#        0.4169263 , 0.54711316, 0.26415763, 0.22342905, 1.61958401,
#        0.31155854, 0.88417521, 1.37230828, 0.34367099, 0.41368146,
#        0.19898464, 0.85368868, 1.28598407, 0.348372  , 0.68716537,
#        1.12054542, 0.47884724, 0.74055403, 0.58852116, 0.83024579,
#        0.83051035, 0.78070574, 0.42879441, 1.47500984, 0.44214586,
#        0.62755315, 0.1678709 , 0.40362379, 0.48493936, 0.92029783,
#        0.49501415, 0.45095106, 0.77998359, 0.23679448, 1.13406418,
#        0.57164328, 0.90379319, 0.85853604, 0.98087414, 0.53599328,
#        0.78816469, 1.23218326, 0.65716623, 1.11236213, 0.20607984,
#        0.48214784, 0.78541783, 0.3938386 , 0.76372604, 0.34513815,
#        1.2011956 , 0.50780521, 0.83570374, 0.44263567, 1.00331319,
#        0.36236163, 0.26241046, 1.41459035, 0.51293605, 0.35903595,
#        0.28936025, 0.73864546, 0.8474576 , 0.22876251, 0.62188502,
#        0.46161006, 0.44019067, 0.27185411, 0.58534832, 0.37079813,
#        0.62282622, 0.33900224, 0.40837221, 0.54670898, 0.71747371,
#        0.54361973, 0.59893795, 0.81798469, 1.16638867, 0.52106181,
#        0.71991976, 0.9737682 , 1.26282586, 0.98054857, 0.82439761,
#        0.66328499, 0.550217  , 0.3921184 , 0.50875301, 0.74378856,
#        0.37546444, 0.56802272, 0.36103993, 0.56821317, 0.25037052,
#        0.31233148, 0.62055286, 0.79458284, 0.85274547, 0.82719489,
#        0.76009743, 0.50608447, 0.22263531, 0.63512844, 0.95730405,
#        1.70237058, 0.71337048, 0.30322703, 0.37406765, 0.73770264,
#        1.25509335, 0.37637843, 0.54494586, 0.26223604, 0.37651935,
#        0.48074308, 1.11199143, 0.39804958, 0.30741607, 0.44784055,
#        0.25195745, 0.66750695, 1.00770805, 0.84849202, 0.35989752,
#        0.48616798, 0.51026691, 0.41645739, 0.35910409, 0.2245488 ,
#        0.51813306, 1.05088186, 0.42775452, 0.27375966, 0.23655916,
#        0.85390211, 0.53045022, 0.78446297, 0.28411985, 0.52602681,
#        1.12025636, 0.31743321, 0.70350519])

# %% [markdown]
# ### Model Coefficients and Intercept

# %%
print("\nModel Coefficients:")
print(pd.DataFrame({'Feature': features, 'Coefficient': model.coef_}))
print("\nModel Intercept:")
print(model.intercept_)
# Out:
# Model Coefficients:
#    Feature  Coefficient
# 0      APD     0.299274
# 1     ATMP    -0.038594
# 2     DEWP     0.022714
# 3      DPD    -0.042289
# 4      GST     0.097111
# 5      MWD     0.001350
# 6     PRES    -0.005752
# 7     WDIR    -0.003561
# 8     WSPD     0.067324
# 9     WTMP     0.007746
# 10      hh     0.009654
#
# Model Intercept:
# 0.6390866880929439

# %% [markdown]
# ### Visualization of Actual vs Predicted Values

# %%
plt.scatter(y_test, y_pred, alpha=0.5, color='blue')
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted Values")
plt.show()

# %% [markdown]
# ### Performance Metrics for Regression Models

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print(f"\nMean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Mean Absolute Error (MAE): 0.08147201988640801
# Mean Squared Error (MSE): 0.012266202948000066
# Root Mean Squared Error (RMSE): 0.11075289137534995

# %% [markdown]
# ### Creating DataFrame to View Results

# %%
results_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print("\nResults DataFrame:")
print(results_df.head())
# Out:
# Results DataFrame:
#       Actual  Predicted
# 1344    0.72   0.830851
# 2887    0.28   0.202740
# 3592    0.26   0.094943
# 3617    0.35   0.304388
# 1813    0.65   0.641006

# %% [markdown]
# ### R² Value Calculation

# %%
r2 = r2_score(y_test, y_pred)
print(f"\nR² Score: {r2}")
# Out:
# R² Score: 0.9164393802291397

# %%
#END

# %% [markdown]
# ### Lasso regression

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error

lasso = Lasso(alpha=1.0)
lasso.fit(X_train, y_train)
y_pred_lasso = lasso.predict(X_test)
lasso_mse = mean_squared_error(y_test, y_pred_lasso)
lasso_r2 = r2_score(y_test, y_pred_lasso)

print("Lasso Regression ")
print("="*20)
print("Mean Squared Error:", lasso_mse)
accuracy = lasso.score(X_test,y_test)
print('Accuracy:',accuracy*100,'%')
print('R2:',lasso_r2*100,'%')
# Out:
# Lasso Regression
# ====================
# Mean Squared Error: 0.14747883899688968
# Accuracy: -0.4664869960942175 %
# R2: -0.4664869960942175 %

# %% [markdown]
# ### Ridge Regression

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=0.2)
ridge.fit(X_train, y_train)
y_pred_ridge = ridge.predict(X_test)
ridge_mse = mean_squared_error(y_test, y_pred_ridge)
ridge_r2 = r2_score(y_test, y_pred_ridge)

print("Ridge Regression ")
print("="*20)
print("Mean Squared Error:",ridge_mse)
accuracy = ridge.score(X_test,y_test)
print('Accuracy:',accuracy*100,'%')
print('R2:',ridge_r2*100,'%')
# Out:
# Ridge Regression
# ====================
# Mean Squared Error: 0.012266711273918651
# Accuracy: 91.64359173784938 %
# R2: 91.64359173784938 %

# %%
#END
